# %% [markdown]
# <a href="https://colab.research.google.com/github/Vengadore/Notebooks/blob/master/Training_Vessels_efficientnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading data

# %%
# !rm -rf *
# !nvidia-smi

# %%
# !wget 'https://correoipn-my.sharepoint.com/:u:/g/personal/ccarrillog1400_alumno_ipn_mx/ERgktnjHms9DroR01IFSAsEBGQipq3SG8sjTZUSEQuRK9Q?download=1'
# !mv 'ERgktnjHms9DroR01IFSAsEBGQipq3SG8sjTZUSEQuRK9Q?download=1' 'DRIVE.rar'
# !unrar x 'DRIVE.rar'
# !rm 'DRIVE.rar'
# Out:
# --2020-10-18 00:24:23--  https://correoipn-my.sharepoint.com/:u:/g/personal/ccarrillog1400_alumno_ipn_mx/ERgktnjHms9DroR01IFSAsEBGQipq3SG8sjTZUSEQuRK9Q?download=1
# Resolving correoipn-my.sharepoint.com (correoipn-my.sharepoint.com)... 13.107.136.9
# Connecting to correoipn-my.sharepoint.com (correoipn-my.sharepoint.com)|13.107.136.9|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/ccarrillog1400_alumno_ipn_mx/Documents/Data%20Bases/Other%20Databases/DRIVE.rar?originalPath=aHR0cHM6Ly9jb3JyZW9pcG4tbXkuc2hhcmVwb2ludC5jb20vOnU6L2cvcGVyc29uYWwvY2NhcnJpbGxvZzE0MDBfYWx1bW5vX2lwbl9teC9FUmdrdG5qSG1zOURyb1IwMUlGU0FzRUJHUWlwcTNTRzhzalRaVVNFUXVSSzlRP3J0aW1lPU9od2dLdnh5MkVn [following]
# --2020-10-18 00:24:23--  https://correoipn-my.sharepoint.com/personal/ccarrillog1400_alumno_ipn_mx/Documents/Data%20Bases/Other%20Databases/DRIVE.rar?originalPath=aHR0cHM6Ly9jb3JyZW9pcG4tbXkuc2hhcmVwb2ludC5jb20vOnU6L2cvcGVyc29uYWwvY2NhcnJpbGxvZzE0MDBfYWx1bW5vX2lwbl9teC9FUmdrdG5qSG1zOURyb1IwMUlGU0FzRUJHUWlwcTNTRzhzalRaVVNFUXVSSzlRP3J0aW1lPU9od2dLdnh5MkVn
# Reusing existing connection to correoipn-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 29611503 (28M) [application/octet-stream]
# Saving to: ‘ERgktnjHms9DroR01IFSAsEBGQipq3SG8sjTZUSEQuRK9Q?download=1’
#
# ERgktnjHms9DroR01IF 100%[===================>]  28.24M   121MB/s    in 0.2s
#
# 2020-10-18 00:24:24 (121 MB/s) - ‘ERgktnjHms9DroR01IFSAsEBGQipq3SG8sjTZUSEQuRK9Q?download=1’ saved [29611503/29611503]
#
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from DRIVE.rar
#
# Creating    test                                                      OK
# Creating    test/1st_manual                                           OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    test/2nd_manual                                           OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    test/images                                               OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    test/mask                                                 OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    training                                                  OK
# Creating    training/1st_manual                                       OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    training/images                                           OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    training/mask                                             OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
# !wget "https://correoipn-my.sharepoint.com/:u:/g/personal/ccarrillog1400_alumno_ipn_mx/EYexeSiuHd5Ho5ggh6RpkoMBbhNKfyFJn6lwrtaDrxt_AA?download=1"
# !mv "EYexeSiuHd5Ho5ggh6RpkoMBbhNKfyFJn6lwrtaDrxt_AA?download=1" "Segmentation.zip"
# !unzip "Segmentation.zip"
# !rm "Segmentation.zip"
# Out:
# --2020-10-18 00:24:25--  https://correoipn-my.sharepoint.com/:u:/g/personal/ccarrillog1400_alumno_ipn_mx/EYexeSiuHd5Ho5ggh6RpkoMBbhNKfyFJn6lwrtaDrxt_AA?download=1
# Resolving correoipn-my.sharepoint.com (correoipn-my.sharepoint.com)... 13.107.136.9
# Connecting to correoipn-my.sharepoint.com (correoipn-my.sharepoint.com)|13.107.136.9|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/ccarrillog1400_alumno_ipn_mx/Documents/Data%20Bases/Temp/Segmentation_pytorch.zip?originalPath=aHR0cHM6Ly9jb3JyZW9pcG4tbXkuc2hhcmVwb2ludC5jb20vOnU6L2cvcGVyc29uYWwvY2NhcnJpbGxvZzE0MDBfYWx1bW5vX2lwbl9teC9FWWV4ZVNpdUhkNUhvNWdnaDZScGtvTUJiaE5LZnlGSm42bHdydGFEcnh0X0FBP3J0aW1lPUtxQXhLX3h5MkVn [following]
# --2020-10-18 00:24:25--  https://correoipn-my.sharepoint.com/personal/ccarrillog1400_alumno_ipn_mx/Documents/Data%20Bases/Temp/Segmentation_pytorch.zip?originalPath=aHR0cHM6Ly9jb3JyZW9pcG4tbXkuc2hhcmVwb2ludC5jb20vOnU6L2cvcGVyc29uYWwvY2NhcnJpbGxvZzE0MDBfYWx1bW5vX2lwbl9teC9FWWV4ZVNpdUhkNUhvNWdnaDZScGtvTUJiaE5LZnlGSm42bHdydGFEcnh0X0FBP3J0aW1lPUtxQXhLX3h5MkVn
# Reusing existing connection to correoipn-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2867798 (2.7M) [application/x-zip-compressed]
# Saving to: ‘EYexeSiuHd5Ho5ggh6RpkoMBbhNKfyFJn6lwrtaDrxt_AA?download=1’
#
# EYexeSiuHd5Ho5ggh6R 100%[===================>]   2.73M  --.-KB/s    in 0.1s
#
# 2020-10-18 00:24:27 (20.6 MB/s) - ‘EYexeSiuHd5Ho5ggh6RpkoMBbhNKfyFJn6lwrtaDrxt_AA?download=1’ saved [2867798/2867798]
#
# Archive:  Segmentation.zip
#   inflating: requeriments.txt
#    creating: segmentation_models.pytorch/
#    creating: segmentation_models.pytorch/.git/
#   inflating: segmentation_models.pytorch/.git/description
#    creating: segmentation_models.pytorch/.git/hooks/
#   inflating: segmentation_models.pytorch/.git/hooks/pre-merge-commit.sample
#   inflating: segmentation_models.pytorch/.git/hooks/pre-commit.sample
#   inflating: segmentation_models.pytorch/.git/hooks/pre-rebase.sample
#   inflating: segmentation_models.pytorch/.git/hooks/pre-applypatch.sample
#   inflating: segmentation_models.pytorch/.git/hooks/commit-msg.sample
#   inflating: segmentation_models.pytorch/.git/hooks/prepare-commit-msg.sample
#   inflating: segmentation_models.pytorch/.git/hooks/applypatch-msg.sample
#   inflating: segmentation_models.pytorch/.git/hooks/pre-receive.sample
#   inflating: segmentation_models.pytorch/.git/hooks/pre-push.sample
#   inflating: segmentation_models.pytorch/.git/hooks/update.sample
#   inflating: segmentation_models.pytorch/.git/hooks/post-update.sample
#   inflating: segmentation_models.pytorch/.git/hooks/fsmonitor-watchman.sample
#    creating: segmentation_models.pytorch/.git/info/
#   inflating: segmentation_models.pytorch/.git/info/exclude
#    creating: segmentation_models.pytorch/.git/branches/
#    creating: segmentation_models.pytorch/.git/refs/
#    creating: segmentation_models.pytorch/.git/refs/heads/
#   inflating: segmentation_models.pytorch/.git/refs/heads/master
#    creating: segmentation_models.pytorch/.git/refs/tags/
#   inflating: segmentation_models.pytorch/.git/refs/tags/v0.1.2
#    creating: segmentation_models.pytorch/.git/refs/remotes/
#    creating: segmentation_models.pytorch/.git/refs/remotes/origin/
#   inflating: segmentation_models.pytorch/.git/refs/remotes/origin/HEAD
#    creating: segmentation_models.pytorch/.git/objects/
#    creating: segmentation_models.pytorch/.git/objects/pack/
#    creating: segmentation_models.pytorch/.git/objects/info/
#    creating: segmentation_models.pytorch/.git/objects/17/
#   inflating: segmentation_models.pytorch/.git/objects/17/6f2777cbfc4101abf9b10d1339c7a3e93f06f2
#    creating: segmentation_models.pytorch/.git/objects/39/
#   inflating: segmentation_models.pytorch/.git/objects/39/4fd2633bf86bc8f4ff230e063004b4e5d29ab1
#    creating: segmentation_models.pytorch/.git/objects/3d/
#   inflating: segmentation_models.pytorch/.git/objects/3d/818f7d38b2a3bbc363ac9b837701a62068ee10
#    creating: segmentation_models.pytorch/.git/objects/c5/
#   inflating: segmentation_models.pytorch/.git/objects/c5/a2bbc70ac803aee0802df92d1694d3e83e89e1
#    creating: segmentation_models.pytorch/.git/objects/88/
#   inflating: segmentation_models.pytorch/.git/objects/88/0c6cfb8574ef5e3847186addb27b46c82b0486
#   inflating: segmentation_models.pytorch/.git/objects/88/77454407cd7584054fabcd56978df58f08f0be
#    creating: segmentation_models.pytorch/.git/objects/ec/
#   inflating: segmentation_models.pytorch/.git/objects/ec/65275623acb8e7cd8ee17c7c6058dd6992eb4f
#   inflating: segmentation_models.pytorch/.git/objects/ec/19d542f1fd8033525ef056adf252041db26e15
#    creating: segmentation_models.pytorch/.git/objects/46/
#   inflating: segmentation_models.pytorch/.git/objects/46/8073474a86c4c02142c2a1bb9b236b9146c4a0
#   inflating: segmentation_models.pytorch/.git/objects/46/67b5c62c126ec7098f575bd827c55ca2560827
#    creating: segmentation_models.pytorch/.git/objects/a3/
#   inflating: segmentation_models.pytorch/.git/objects/a3/b242a2895d317f7720eb4972417b39a8e8dfc8
#    creating: segmentation_models.pytorch/.git/objects/09/
#   inflating: segmentation_models.pytorch/.git/objects/09/4ca0ec463678fedb9ff2cb4a679ef48e0c2ddb
#    creating: segmentation_models.pytorch/.git/objects/33/
#   inflating: segmentation_models.pytorch/.git/objects/33/e1abb7c10e00333402600b388e197618202fd8
#    creating: segmentation_models.pytorch/.git/objects/b0/
#   inflating: segmentation_models.pytorch/.git/objects/b0/f82d00d808f702081703035ec11122c8cb2a07
#    creating: segmentation_models.pytorch/.git/objects/8d/
#   inflating: segmentation_models.pytorch/.git/objects/8d/ee21e879e510b0d1dff4f941077e87a7de2952
#    creating: segmentation_models.pytorch/.git/objects/c1/
#   inflating: segmentation_models.pytorch/.git/objects/c1/8f212c2c43937df927edc89248a2c02978aa01
#   inflating: segmentation_models.pytorch/.git/objects/c1/9a5eaa8f0c9faa912bb34104f8b876dfa6aede
#    creating: segmentation_models.pytorch/.git/objects/9f/
#   inflating: segmentation_models.pytorch/.git/objects/9f/c0cdefa50d85531802af35c77146848a3fdc84
#    creating: segmentation_models.pytorch/.git/objects/db/
#   inflating: segmentation_models.pytorch/.git/objects/db/8a5fd9b30487467e80db30fce3d2d95cebfa9c
#    creating: segmentation_models.pytorch/.git/objects/40/
#   inflating: segmentation_models.pytorch/.git/objects/40/72bed7bd72441e8c823f5d0355697f4ed83887
#    creating: segmentation_models.pytorch/.git/objects/31/
#   inflating: segmentation_models.pytorch/.git/objects/31/09e0fa253d5ac6ab0bef769c3a2a6d7b6edc15
#    creating: segmentation_models.pytorch/.git/objects/49/
#   inflating: segmentation_models.pytorch/.git/objects/49/81ae84695e80dd20b508914b1783dd6d8b508f
#    creating: segmentation_models.pytorch/.git/objects/77/
#   inflating: segmentation_models.pytorch/.git/objects/77/a16ab4e281a68b84ab7aff548fb8fd1c138958
#    creating: segmentation_models.pytorch/.git/objects/ad/
#   inflating: segmentation_models.pytorch/.git/objects/ad/2eb978bb442ffdef2306780a7c36e48defe4e2
#    creating: segmentation_models.pytorch/.git/objects/2e/
#   inflating: segmentation_models.pytorch/.git/objects/2e/999c54705527199794be8fa3864a58754d6c00
#    creating: segmentation_models.pytorch/.git/objects/fc/
#   inflating: segmentation_models.pytorch/.git/objects/fc/a801c3e26bc990bd3282ea3d6e4276006ccf40
#    creating: segmentation_models.pytorch/.git/objects/b2/
#   inflating: segmentation_models.pytorch/.git/objects/b2/cc4f509e8ba0d699613fe80350ddb7bdd51efd
#    creating: segmentation_models.pytorch/.git/objects/4a/
#   inflating: segmentation_models.pytorch/.git/objects/4a/a4ce69fe3d320d9d32069b05052d9fd24b2337
#   inflating: segmentation_models.pytorch/.git/objects/4a/c0664d91b5ea14c666032fb42696595aee4199
#    creating: segmentation_models.pytorch/.git/objects/cc/
#   inflating: segmentation_models.pytorch/.git/objects/cc/8a79aadfff36a6d49dbb89592e315fa6463a98
#    creating: segmentation_models.pytorch/.git/objects/6e/
#   inflating: segmentation_models.pytorch/.git/objects/6e/6a041f4c98862e3278d33bc3f52a650ff684e5
#    creating: segmentation_models.pytorch/.git/objects/df/
#   inflating: segmentation_models.pytorch/.git/objects/df/ad7d8dfe0320fb6235fe84c614cb044857d363
#   inflating: segmentation_models.pytorch/.git/objects/df/148eea77c7bc74d31c75b768fbce8c930e23c5
#    creating: segmentation_models.pytorch/.git/objects/cb/
#   inflating: segmentation_models.pytorch/.git/objects/cb/54861b4896d6034796684ae35217cf277cb6eb
#   inflating: segmentation_models.pytorch/.git/objects/cb/0e8ae84dab61760f1be4ca476492e12682599c
#    creating: segmentation_models.pytorch/.git/objects/a6/
#   inflating: segmentation_models.pytorch/.git/objects/a6/1390f71f1bfe1576ba1c24c14e7d107c9eff69
#    creating: segmentation_models.pytorch/.git/objects/84/
#   inflating: segmentation_models.pytorch/.git/objects/84/307455424bf36ebc55edbac772782930e1dfa9
#    creating: segmentation_models.pytorch/.git/objects/41/
#   inflating: segmentation_models.pytorch/.git/objects/41/b747acd00a7d8781893b82f014ec9e83dd97c1
#    creating: segmentation_models.pytorch/.git/objects/24/
#   inflating: segmentation_models.pytorch/.git/objects/24/4868fdff48769d958a43d8ded28df2aafcca9d
#    creating: segmentation_models.pytorch/.git/objects/de/
#   inflating: segmentation_models.pytorch/.git/objects/de/812640fb0f41960cd26387c85d5e2fe06ff59b
#    creating: segmentation_models.pytorch/.git/objects/16/
#   inflating: segmentation_models.pytorch/.git/objects/16/a04016b915954c3b0dfb58f4098436375607d3
#   inflating: segmentation_models.pytorch/.git/objects/16/7afe24b9e9fc9e2371327129f52fda563a17f0
#    creating: segmentation_models.pytorch/.git/objects/fa/
#   inflating: segmentation_models.pytorch/.git/objects/fa/13f8d0ca3877111714e303e3be5478f1ad2a14
#    creating: segmentation_models.pytorch/.git/objects/96/
#   inflating: segmentation_models.pytorch/.git/objects/96/22130204a0172d43a5f32f4ade065e100f746e
#    creating: segmentation_models.pytorch/.git/objects/e5/
#   inflating: segmentation_models.pytorch/.git/objects/e5/ffad15a69e1dfcafc92f47c79bff28d6dfd474
#    creating: segmentation_models.pytorch/.git/objects/27/
#   inflating: segmentation_models.pytorch/.git/objects/27/5c5ad2eff5fbb2ee2967f9f9ec5af84b43ea78
#    creating: segmentation_models.pytorch/.git/objects/9a/
#   inflating: segmentation_models.pytorch/.git/objects/9a/cd50af70bad232b3459f1c2705fd7c041285d6
#   inflating: segmentation_models.pytorch/.git/objects/9a/667e83a30c87fe2f367222c5481566ee7a285b
#    creating: segmentation_models.pytorch/.git/objects/13/
#   inflating: segmentation_models.pytorch/.git/objects/13/15859dff7c9d1f49b64c39fdd6eab5880de0dc
#    creating: segmentation_models.pytorch/.git/objects/e9/
#   inflating: segmentation_models.pytorch/.git/objects/e9/cd7afbfd0b46891d32b8379a54466c9087f8a9
#    creating: segmentation_models.pytorch/.git/objects/50/
#   inflating: segmentation_models.pytorch/.git/objects/50/689f72c1d4e484c2775c20c556c1d6e1e25fa3
#    creating: segmentation_models.pytorch/.git/objects/29/
#   inflating: segmentation_models.pytorch/.git/objects/29/4a07aae54a803c9937324451ffccb7b3aaef0e
#    creating: segmentation_models.pytorch/.git/objects/ae/
#   inflating: segmentation_models.pytorch/.git/objects/ae/443fd7524a4abeffb794d029b5ffc62042bcbe
#    creating: segmentation_models.pytorch/.git/objects/45/
#   inflating: segmentation_models.pytorch/.git/objects/45/c8375d9d38a3aafe07a62b89f1b81afb195935
#   inflating: segmentation_models.pytorch/.git/objects/45/27b5a6ece45b1207478dfdea248cd8e94c97b7
#    creating: segmentation_models.pytorch/.git/objects/ee/
#   inflating: segmentation_models.pytorch/.git/objects/ee/896af3ca6edbb940404c57dcf6447ba0a1f576
#    creating: segmentation_models.pytorch/.git/objects/80/
#   inflating: segmentation_models.pytorch/.git/objects/80/0bb0dd2d700e232647d33c4fd77c0757010172
#    creating: segmentation_models.pytorch/.git/objects/35/
#   inflating: segmentation_models.pytorch/.git/objects/35/65dd777952c07da5d9ca1fce6d21a181cc31cb
#    creating: segmentation_models.pytorch/.git/objects/8a/
#   inflating: segmentation_models.pytorch/.git/objects/8a/e59de7cc0f4bb4800a0875dfb705da1a38f6fa
#    creating: segmentation_models.pytorch/.git/objects/10/
#   inflating: segmentation_models.pytorch/.git/objects/10/fc2c4d793503b25e6bce10c2d856a325124e71
#    creating: segmentation_models.pytorch/.git/objects/8e/
#   inflating: segmentation_models.pytorch/.git/objects/8e/d41cd2ee6a2c0023862b17e8d7fe356c5a5f13
#    creating: segmentation_models.pytorch/.git/objects/62/
#   inflating: segmentation_models.pytorch/.git/objects/62/ba22d0eb9bcb08f237a010895e8503a2034655
#    creating: segmentation_models.pytorch/.git/objects/00/
#   inflating: segmentation_models.pytorch/.git/objects/00/f748e7146830dccfbe37a09eb41d016cd0f464
#    creating: segmentation_models.pytorch/.git/objects/2d/
#   inflating: segmentation_models.pytorch/.git/objects/2d/af90a47d3822f02c569a20ee947ec41112185a
#    creating: segmentation_models.pytorch/.git/objects/c3/
#   inflating: segmentation_models.pytorch/.git/objects/c3/d30af36a7df2245ac0b15388d308f4df71a085
#    creating: segmentation_models.pytorch/.git/objects/02/
#   inflating: segmentation_models.pytorch/.git/objects/02/95d77b141eaca7b478778a9a8045174558ca5a
#    creating: segmentation_models.pytorch/.git/objects/f3/
#   inflating: segmentation_models.pytorch/.git/objects/f3/62a37d4b661bc18f8cde31b9c54b8b974414fe
#    creating: segmentation_models.pytorch/.git/objects/4f/
#   inflating: segmentation_models.pytorch/.git/objects/4f/aebe4238049e754716d3561b46c6955a117da3
#    creating: segmentation_models.pytorch/.git/objects/6a/
#   inflating: segmentation_models.pytorch/.git/objects/6a/26d57217858cf07e82ca10dbbadae0a72e0998
#    creating: segmentation_models.pytorch/.git/objects/86/
#   inflating: segmentation_models.pytorch/.git/objects/86/57b7ee7343309e86253a3ed2a6d038d01f538d
#    creating: segmentation_models.pytorch/.git/objects/c7/
#   inflating: segmentation_models.pytorch/.git/objects/c7/e05ebe1ef3761c8ba00c70571931e33f46787f
#    creating: segmentation_models.pytorch/.git/objects/99/
#   inflating: segmentation_models.pytorch/.git/objects/99/17f8f14fdc1bbfe63846412d6f5db774617478
#    creating: segmentation_models.pytorch/.git/objects/06/
#   inflating: segmentation_models.pytorch/.git/objects/06/493c78f864ca677c5e9bb484fd039ab3498b7b
#    creating: segmentation_models.pytorch/.git/objects/79/
#   inflating: segmentation_models.pytorch/.git/objects/79/feba851cac561426164e53dac351be22b59608
#    creating: segmentation_models.pytorch/.git/objects/ba/
#   inflating: segmentation_models.pytorch/.git/objects/ba/6878e0c9f397907149a4dc6f96b6020e2a7f22
#    creating: segmentation_models.pytorch/.git/objects/5d/
#   inflating: segmentation_models.pytorch/.git/objects/5d/7481dba7951e5572abccc2e7e1266118adf932
#    creating: segmentation_models.pytorch/.git/objects/a0/
#   inflating: segmentation_models.pytorch/.git/objects/a0/6e2c12cf054191a52246abcc090ca5e1d99d31
#    creating: segmentation_models.pytorch/.git/objects/5f/
#   inflating: segmentation_models.pytorch/.git/objects/5f/7e07da496ab4b9f24b017ca3a6d491d9a60192
#    creating: segmentation_models.pytorch/.git/objects/44/
#   inflating: segmentation_models.pytorch/.git/objects/44/e05f49064eac421be2124a9f433b6dc71796d9
#    creating: segmentation_models.pytorch/.git/objects/1c/
#   inflating: segmentation_models.pytorch/.git/objects/1c/d1e9909e3dfd1eadc19989266f4fe22f6c8ca1
#    creating: segmentation_models.pytorch/.git/objects/f6/
#   inflating: segmentation_models.pytorch/.git/objects/f6/0b195e0a118b5c934b57f90bc7c44fa7741b83
#    creating: segmentation_models.pytorch/.git/objects/76/
#   inflating: segmentation_models.pytorch/.git/objects/76/c8d8acda8df20cc67422217e602390df365258
#    creating: segmentation_models.pytorch/.git/objects/d7/
#   inflating: segmentation_models.pytorch/.git/objects/d7/dd63e98d08c76f8866f9a3d894858d0e69f694
#   inflating: segmentation_models.pytorch/.git/shallow
#   inflating: segmentation_models.pytorch/.git/packed-refs
#    creating: segmentation_models.pytorch/.git/logs/
#    creating: segmentation_models.pytorch/.git/logs/refs/
#    creating: segmentation_models.pytorch/.git/logs/refs/remotes/
#    creating: segmentation_models.pytorch/.git/logs/refs/remotes/origin/
#   inflating: segmentation_models.pytorch/.git/logs/refs/remotes/origin/HEAD
#    creating: segmentation_models.pytorch/.git/logs/refs/heads/
#   inflating: segmentation_models.pytorch/.git/logs/refs/heads/master
#   inflating: segmentation_models.pytorch/.git/logs/HEAD
#   inflating: segmentation_models.pytorch/.git/HEAD
#   inflating: segmentation_models.pytorch/.git/config
#   inflating: segmentation_models.pytorch/.git/index
#    creating: segmentation_models.pytorch/.github/
#   inflating: segmentation_models.pytorch/.github/FUNDING.yml
#   inflating: segmentation_models.pytorch/.gitignore
#   inflating: segmentation_models.pytorch/.travis.yml
#   inflating: segmentation_models.pytorch/HALLOFFAME.md
#   inflating: segmentation_models.pytorch/LICENSE
#   inflating: segmentation_models.pytorch/MANIFEST.in
#   inflating: segmentation_models.pytorch/README.md
#   inflating: segmentation_models.pytorch/__init__.py
#    creating: segmentation_models.pytorch/docker/
#   inflating: segmentation_models.pytorch/docker/Dockerfile
#   inflating: segmentation_models.pytorch/docker/Dockerfile.dev
#    creating: segmentation_models.pytorch/examples/
#   inflating: segmentation_models.pytorch/examples/cars segmentation (camvid).ipynb
#    creating: segmentation_models.pytorch/misc/
#   inflating: segmentation_models.pytorch/misc/generate_table.py
#    creating: segmentation_models.pytorch/pics/
#   inflating: segmentation_models.pytorch/pics/logo-small-h300.png
#   inflating: segmentation_models.pytorch/pics/logo-small-w300.png
#   inflating: segmentation_models.pytorch/requirements.txt
#    creating: segmentation_models.pytorch/segmentation_models_pytorch/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/__init__.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/__version__.py
#    creating: segmentation_models.pytorch/segmentation_models_pytorch/base/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/base/__init__.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/base/heads.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/base/initialization.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/base/model.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/base/modules.py
#    creating: segmentation_models.pytorch/segmentation_models_pytorch/deeplabv3/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/deeplabv3/__init__.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/deeplabv3/decoder.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/deeplabv3/model.py
#    creating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/__init__.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/_base.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/_preprocessing.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/_utils.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/densenet.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/dpn.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/efficientnet.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/inceptionresnetv2.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/inceptionv4.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/mobilenet.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/resnet.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/senet.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/timm_efficientnet.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/vgg.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/encoders/xception.py
#    creating: segmentation_models.pytorch/segmentation_models_pytorch/fpn/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/fpn/__init__.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/fpn/decoder.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/fpn/model.py
#    creating: segmentation_models.pytorch/segmentation_models_pytorch/linknet/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/linknet/__init__.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/linknet/decoder.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/linknet/model.py
#    creating: segmentation_models.pytorch/segmentation_models_pytorch/pan/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/pan/__init__.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/pan/decoder.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/pan/model.py
#    creating: segmentation_models.pytorch/segmentation_models_pytorch/pspnet/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/pspnet/__init__.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/pspnet/decoder.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/pspnet/model.py
#    creating: segmentation_models.pytorch/segmentation_models_pytorch/unet/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/unet/__init__.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/unet/decoder.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/unet/model.py
#    creating: segmentation_models.pytorch/segmentation_models_pytorch/utils/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/utils/__init__.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/utils/base.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/utils/functional.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/utils/losses.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/utils/meter.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/utils/metrics.py
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch/utils/train.py
#   inflating: segmentation_models.pytorch/setup.py
#    creating: segmentation_models.pytorch/tests/
#   inflating: segmentation_models.pytorch/tests/test_models.py
#   inflating: segmentation_models.pytorch/tests/test_preprocessing.py
#    creating: segmentation_models.pytorch/tests/__pycache__/
#   inflating: segmentation_models.pytorch/tests/__pycache__/test_models.cpython-37-pytest-6.1.1.pyc
#    creating: segmentation_models.pytorch/build/
#    creating: segmentation_models.pytorch/build/lib/
#    creating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/__init__.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/__version__.py
#    creating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/base/
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/base/heads.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/base/initialization.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/base/model.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/base/modules.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/base/__init__.py
#    creating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/deeplabv3/
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/deeplabv3/decoder.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/deeplabv3/model.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/deeplabv3/__init__.py
#    creating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/densenet.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/dpn.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/efficientnet.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/inceptionresnetv2.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/inceptionv4.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/mobilenet.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/resnet.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/senet.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/timm_efficientnet.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/vgg.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/xception.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/_base.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/_preprocessing.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/_utils.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/encoders/__init__.py
#    creating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/fpn/
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/fpn/decoder.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/fpn/model.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/fpn/__init__.py
#    creating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/linknet/
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/linknet/decoder.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/linknet/model.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/linknet/__init__.py
#    creating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/pan/
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/pan/decoder.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/pan/model.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/pan/__init__.py
#    creating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/pspnet/
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/pspnet/decoder.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/pspnet/model.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/pspnet/__init__.py
#    creating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/unet/
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/unet/decoder.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/unet/model.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/unet/__init__.py
#    creating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/utils/
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/utils/base.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/utils/functional.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/utils/losses.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/utils/meter.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/utils/metrics.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/utils/train.py
#   inflating: segmentation_models.pytorch/build/lib/segmentation_models_pytorch/utils/__init__.py
#    creating: segmentation_models.pytorch/build/bdist.linux-x86_64/
#    creating: segmentation_models.pytorch/segmentation_models_pytorch.egg-info/
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch.egg-info/PKG-INFO
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch.egg-info/dependency_links.txt
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch.egg-info/requires.txt
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch.egg-info/top_level.txt
#   inflating: segmentation_models.pytorch/segmentation_models_pytorch.egg-info/SOURCES.txt
#    creating: segmentation_models.pytorch/dist/
#   inflating: segmentation_models.pytorch/dist/segmentation_models_pytorch-0.1.2-py3.7.egg
#    creating: segmentation_models.pytorch/.pytest_cache/
#    creating: segmentation_models.pytorch/.pytest_cache/v/
#    creating: segmentation_models.pytorch/.pytest_cache/v/cache/
#   inflating: segmentation_models.pytorch/.pytest_cache/v/cache/stepwise
#   inflating: segmentation_models.pytorch/.pytest_cache/v/cache/nodeids
#   inflating: segmentation_models.pytorch/.pytest_cache/README.md
#   inflating: segmentation_models.pytorch/.pytest_cache/.gitignore
#   inflating: segmentation_models.pytorch/.pytest_cache/CACHEDIR.TAG

# %%
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# !pip install -r "./requeriments.txt"
# Out:
# Collecting git+https://github.com/qubvel/segmentation_models.pytorch
#   Cloning https://github.com/qubvel/segmentation_models.pytorch to /tmp/pip-req-build-_bfz2ohg
#   Running command git clone -q https://github.com/qubvel/segmentation_models.pytorch /tmp/pip-req-build-_bfz2ohg
# Requirement already satisfied: torchvision>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from segmentation-models-pytorch==0.1.2) (0.7.0+cu101)
# Collecting pretrainedmodels==0.7.4
#   Downloading https://files.pythonhosted.org/packages/84/0e/be6a0e58447ac16c938799d49bfb5fb7a80ac35e137547fc6cee2c08c4cf/pretrainedmodels-0.7.4.tar.gz (58kB)
#      |████████████████████████████████| 61kB 2.8MB/s
# Collecting efficientnet-pytorch==0.6.3
#   Downloading https://files.pythonhosted.org/packages/b8/cb/0309a6e3d404862ae4bc017f89645cf150ac94c14c88ef81d215c8e52925/efficientnet_pytorch-0.6.3.tar.gz
# Collecting timm==0.1.20
#   Downloading https://files.pythonhosted.org/packages/89/26/ba294669cc5cc4d09efd1964c8df752dc0955ac26f86bdeec582aed77d1d/timm-0.1.20-py3-none-any.whl (161kB)
#      |████████████████████████████████| 163kB 10.7MB/s
# Requirement already satisfied: torch==1.6.0 in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->segmentation-models-pytorch==0.1.2) (1.6.0+cu101)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->segmentation-models-pytorch==0.1.2) (7.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.3.0->segmentation-models-pytorch==0.1.2) (1.18.5)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.2) (4.41.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0->torchvision>=0.3.0->segmentation-models-pytorch==0.1.2) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.1.2) (1.15.0)
# Building wheels for collected packages: segmentation-models-pytorch, pretrainedmodels, efficientnet-pytorch
#   Building wheel for segmentation-models-pytorch (setup.py) ... done
#   Created wheel for segmentation-models-pytorch: filename=segmentation_models_pytorch-0.1.2-cp36-none-any.whl size=53925 sha256=7e0180af4900016780bcdd3e8462661f8f2683c58bd0c42ce7a1d6e96bec26fa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jflg4t1i/wheels/79/3f/09/1587a252e0314d26ad242d6d2e165622ab95c95e5cfe4b942c
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp36-none-any.whl size=60964 sha256=f98eeea511cdec76d627d3c1422432769831e32e301e50e595ec8ee13e93e0ed
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-cp36-none-any.whl size=12421 sha256=0e348df46fd34a90bed26243af9cc356b60fed03f89ff10b4071b5d30cc497a8
#   Stored in directory: /root/.cache/pip/wheels/42/1e/a9/2a578ba9ad04e776e80bf0f70d8a7f4c29ec0718b92d8f6ccd
# Successfully built segmentation-models-pytorch pretrainedmodels efficientnet-pytorch
# Installing collected packages: munch, pretrainedmodels, efficientnet-pytorch, timm, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.6.3 munch-2.5.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.1.2 timm-0.1.20
# Collecting albumentations==0.4.6
#   Downloading https://files.pythonhosted.org/packages/92/33/1c459c2c9a4028ec75527eff88bc4e2d256555189f42af4baf4d7bd89233/albumentations-0.4.6.tar.gz (117kB)
#      |████████████████████████████████| 122kB 5.4MB/s
# Requirement already satisfied: asgiref==3.2.10 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 2)) (3.2.10)
# Requirement already satisfied: async-generator==1.10 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 3)) (1.10)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 4)) (0.2.0)
# Collecting brotlipy==0.7.0
#   Downloading https://files.pythonhosted.org/packages/b8/e6/be86d2d6565fcf4bd82cca288ac1e264a50dbfa41bef86b63b5d69252fca/brotlipy-0.7.0-cp36-cp36m-manylinux1_x86_64.whl (920kB)
#      |████████████████████████████████| 921kB 14.0MB/s
# Requirement already satisfied: certifi==2020.6.20 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 6)) (2020.6.20)
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 7)) (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 8)) (0.10.0)
# Requirement already satisfied: decorator==4.4.2 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 9)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 10)) (0.6.0)
# Collecting Django==3.1.2
#   Downloading https://files.pythonhosted.org/packages/50/22/4c91847beceadbb54b5a518909ed5000bb1777168c7d6b087e8f79e5e05b/Django-3.1.2-py3-none-any.whl (7.8MB)
#      |████████████████████████████████| 7.8MB 27.7MB/s
# Requirement already satisfied: efficientnet-pytorch==0.6.3 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 12)) (0.6.3)
# Requirement already satisfied: entrypoints==0.3 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 13)) (0.3)
# Collecting future==0.18.2
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 41.3MB/s
# Requirement already satisfied: image==1.5.32 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 15)) (1.5.32)
# Collecting imageio==2.9.0
#   Downloading https://files.pythonhosted.org/packages/6e/57/5d899fae74c1752f52869b613a8210a2480e1a69688e65df6cb26117d45d/imageio-2.9.0-py3-none-any.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 53.1MB/s
# Collecting imgaug==0.4.0
#   Downloading https://files.pythonhosted.org/packages/66/b1/af3142c4a85cba6da9f4ebb5ff4e21e2616309552caca5e8acefe9840622/imgaug-0.4.0-py2.py3-none-any.whl (948kB)
#      |████████████████████████████████| 952kB 36.9MB/s
# Requirement already satisfied: iniconfig==1.1.1 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 18)) (1.1.1)
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 19)) (0.2.0)
# Requirement already satisfied: Jinja2==2.11.2 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 20)) (2.11.2)
# Collecting json5==0.9.5
#   Downloading https://files.pythonhosted.org/packages/2b/81/22bf51a5bc60dde18bb6164fd597f18ee683de8670e141364d9c432dd3cf/json5-0.9.5-py2.py3-none-any.whl
# Requirement already satisfied: kiwisolver==1.2.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 22)) (1.2.0)
# Collecting matplotlib==3.3.2
#   Downloading https://files.pythonhosted.org/packages/cd/d6/8c4dfb23151d5a494c66ebbfdb5c8c433b44ec07fae52da5939fcda0943f/matplotlib-3.3.2-cp36-cp36m-manylinux1_x86_64.whl (11.6MB)
#      |████████████████████████████████| 11.6MB 152kB/s
# Collecting mock==4.0.2
#   Downloading https://files.pythonhosted.org/packages/cd/74/d72daf8dff5b6566db857cfd088907bb0355f5dd2914c4b3ef065c790735/mock-4.0.2-py3-none-any.whl
# Requirement already satisfied: munch==2.5.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 25)) (2.5.0)
# Requirement already satisfied: networkx==2.5 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 26)) (2.5)
# Collecting numpy==1.19.2
#   Downloading https://files.pythonhosted.org/packages/63/97/af8a92864a04bfa48f1b5c9b1f8bf2ccb2847f24530026f26dd223de4ca0/numpy-1.19.2-cp36-cp36m-manylinux2010_x86_64.whl (14.5MB)
#      |████████████████████████████████| 14.5MB 240kB/s
# Collecting opencv-python==4.4.0.44
#   Downloading https://files.pythonhosted.org/packages/a2/72/134fdc8d766a6004ee96ce84446f38457a6345fc0ce85721326cbf2adc87/opencv_python-4.4.0.44-cp36-cp36m-manylinux2014_x86_64.whl (49.5MB)
#      |████████████████████████████████| 49.5MB 60kB/s
# Requirement already satisfied: packaging==20.4 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 29)) (20.4)
# Requirement already satisfied: pandocfilters==1.4.2 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 30)) (1.4.2)
# Collecting parso==0.7.0
#   Downloading https://files.pythonhosted.org/packages/b5/61/998cce9e7476de000d031874df26a18f67cb73448164fc44a98f0c55920b/parso-0.7.0-py2.py3-none-any.whl (100kB)
#      |████████████████████████████████| 102kB 14.9MB/s
# Collecting Pillow==8.0.0
#   Downloading https://files.pythonhosted.org/packages/a6/9c/829c74f7f7f129616dfb6f75afd72529f895d29db71c7aeb46b02fcfb26d/Pillow-8.0.0-cp36-cp36m-manylinux1_x86_64.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 31.3MB/s
# Collecting pluggy==0.13.1
#   Downloading https://files.pythonhosted.org/packages/a0/28/85c7aa31b80d150b772fbe4a229487bc6644da9ccb7e427dd8cc60cb8a62/pluggy-0.13.1-py2.py3-none-any.whl
# Requirement already satisfied: pretrainedmodels==0.7.4 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 34)) (0.7.4)
# Requirement already satisfied: prometheus-client==0.8.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 35)) (0.8.0)
# Requirement already satisfied: ptyprocess==0.6.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 36)) (0.6.0)
# Requirement already satisfied: py==1.9.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 37)) (1.9.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 38)) (2.4.7)
# Collecting pytest==6.1.1
#   Downloading https://files.pythonhosted.org/packages/d6/36/9e022b76a3ac440e1d750c64fa6152469f988efe0c568b945e396e2693b5/pytest-6.1.1-py3-none-any.whl (272kB)
#      |████████████████████████████████| 276kB 62.4MB/s
# Requirement already satisfied: python-dateutil==2.8.1 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 40)) (2.8.1)
# Collecting pytz==2020.1
#   Downloading https://files.pythonhosted.org/packages/4f/a4/879454d49688e2fad93e59d7d4efda580b783c745fd2ec2a3adf87b0808d/pytz-2020.1-py2.py3-none-any.whl (510kB)
#      |████████████████████████████████| 512kB 56.6MB/s
# Requirement already satisfied: PyWavelets==1.1.1 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 42)) (1.1.1)
# Collecting PyYAML==5.3.1
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 54.4MB/s
# Requirement already satisfied: pyzmq==19.0.2 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 44)) (19.0.2)
# Collecting scikit-image==0.17.2
#   Downloading https://files.pythonhosted.org/packages/0e/ba/53e1bfbdfd0f94514d71502e3acea494a8b4b57c457adbc333ef386485da/scikit_image-0.17.2-cp36-cp36m-manylinux1_x86_64.whl (12.4MB)
#      |████████████████████████████████| 12.4MB 253kB/s
# Collecting scipy==1.5.2
#   Downloading https://files.pythonhosted.org/packages/2b/a8/f4c66eb529bb252d50e83dbf2909c6502e2f857550f22571ed8556f62d95/scipy-1.5.2-cp36-cp36m-manylinux1_x86_64.whl (25.9MB)
#      |████████████████████████████████| 25.9MB 93kB/s
# Requirement already satisfied: Send2Trash==1.5.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 47)) (1.5.0)
# Requirement already satisfied: Shapely==1.7.1 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 48)) (1.7.1)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 49)) (1.15.0)
# Collecting sqlparse==0.4.1
#   Downloading https://files.pythonhosted.org/packages/14/05/6e8eb62ca685b10e34051a80d7ea94b7137369d8c0be5c3b9d9b6e3f5dae/sqlparse-0.4.1-py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 8.8MB/s
# Requirement already satisfied: terminado==0.9.1 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 51)) (0.9.1)
# Requirement already satisfied: testpath==0.4.4 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 52)) (0.4.4)
# Requirement already satisfied: timm==0.1.20 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 53)) (0.1.20)
# Requirement already satisfied: toml==0.10.1 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 54)) (0.10.1)
# Requirement already satisfied: torch==1.6.0+cu101 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 55)) (1.6.0+cu101)
# Requirement already satisfied: torchvision==0.7.0+cu101 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 56)) (0.7.0+cu101)
# Collecting tornado==6.0.4
#   Downloading https://files.pythonhosted.org/packages/95/84/119a46d494f008969bf0c775cb2c6b3579d3c4cc1bb1b41a022aa93ee242/tornado-6.0.4.tar.gz (496kB)
#      |████████████████████████████████| 501kB 51.9MB/s
# Collecting tqdm==4.50.2
#   Downloading https://files.pythonhosted.org/packages/bd/cf/f91813073e4135c1183cadf968256764a6fe4e35c351d596d527c0540461/tqdm-4.50.2-py2.py3-none-any.whl (70kB)
#      |████████████████████████████████| 71kB 10.3MB/s
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 59)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /usr/local/lib/python3.6/dist-packages (from -r ./requeriments.txt (line 60)) (3.5.1)
# Collecting zipp==3.3.1
#   Downloading https://files.pythonhosted.org/packages/64/f2/0aa52375e14863b377bc9eb58fde6ec48e0a7f73fdf91c9876669559fe45/zipp-3.3.1-py3-none-any.whl
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from brotlipy==0.7.0->-r ./requeriments.txt (line 5)) (1.14.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2==2.11.2->-r ./requeriments.txt (line 20)) (1.1.1)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from pluggy==0.13.1->-r ./requeriments.txt (line 33)) (2.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest==6.1.1->-r ./requeriments.txt (line 39)) (20.2.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.6/dist-packages (from scikit-image==0.17.2->-r ./requeriments.txt (line 45)) (2020.9.3)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (5.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0.0->brotlipy==0.7.0->-r ./requeriments.txt (line 5)) (2.20)
# Requirement already satisfied: jupyter-client>=5.2.0 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (5.3.5)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (4.6.3)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (4.3.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (5.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (5.0.7)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (4.10.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (0.8.4)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (2.6.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (2.6.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (5.5.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (50.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipykernel->notebook>=4.4.1->widgetsnbextension==3.5.1->-r ./requeriments.txt (line 60)) (0.2.5)
# Building wheels for collected packages: albumentations, future, PyYAML, tornado
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-0.4.6-cp36-none-any.whl size=65165 sha256=ac7e61bafc51b1c7d5d1b515b0ffab74edada77c286ba378972fe210f4de167c
#   Stored in directory: /root/.cache/pip/wheels/c7/f4/89/56d1bee5c421c36c1a951eeb4adcc32fbb82f5344c086efa14
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-cp36-none-any.whl size=491057 sha256=aac61520ad5dd0faec3f0046ae86fb5ca33d552f15c6c7c1d5824634126c478b
#   Stored in directory: /root/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44619 sha256=d59af3c7cedb65aa86c16a6018f957e44ee792aefc80a53a0651c8c5c8b4c54f
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-6.0.4-cp36-cp36m-linux_x86_64.whl size=427637 sha256=9e4a55b53f612600578a2f77b96187e3f86273e6bdd2688fff3f6cd89eeb6bd8
#   Stored in directory: /root/.cache/pip/wheels/93/84/2f/409c7b2bb3afc3aa727f7ee8787975e0793f74d1165f4d0104
# Successfully built albumentations future PyYAML tornado
# ERROR: tensorflow 2.3.0 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.2 which is incompatible.
# ERROR: tensorflow 2.3.0 has requirement scipy==1.4.1, but you'll have scipy 1.5.2 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement tornado~=5.1.0; python_version >= "3.0", but you'll have tornado 6.0.4 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: numpy, scipy, Pillow, opencv-python, imageio, matplotlib, scikit-image, imgaug, PyYAML, albumentations, brotlipy, sqlparse, pytz, Django, future, json5, mock, parso, pluggy, pytest, tornado, tqdm, zipp
#   Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
#   Found existing installation: imageio 2.4.1
#     Uninstalling imageio-2.4.1:
#       Successfully uninstalled imageio-2.4.1
#   Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Found existing installation: scikit-image 0.16.2
#     Uninstalling scikit-image-0.16.2:
#       Successfully uninstalled scikit-image-0.16.2
#   Found existing installation: imgaug 0.2.9
#     Uninstalling imgaug-0.2.9:
#       Successfully uninstalled imgaug-0.2.9
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Found existing installation: albumentations 0.1.12
#     Uninstalling albumentations-0.1.12:
#       Successfully uninstalled albumentations-0.1.12
#   Found existing installation: sqlparse 0.3.1
#     Uninstalling sqlparse-0.3.1:
#       Successfully uninstalled sqlparse-0.3.1
#   Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Found existing installation: Django 3.1.1
#     Uninstalling Django-3.1.1:
#       Successfully uninstalled Django-3.1.1
#   Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Found existing installation: parso 0.7.1
#     Uninstalling parso-0.7.1:
#       Successfully uninstalled parso-0.7.1
#   Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
#   Found existing installation: zipp 3.2.0
#     Uninstalling zipp-3.2.0:
#       Successfully uninstalled zipp-3.2.0
# Successfully installed Django-3.1.2 Pillow-8.0.0 PyYAML-5.3.1 albumentations-0.4.6 brotlipy-0.7.0 future-0.18.2 imageio-2.9.0 imgaug-0.4.0 json5-0.9.5 matplotlib-3.3.2 mock-4.0.2 numpy-1.19.2 opencv-python-4.4.0.44 parso-0.7.0 pluggy-0.13.1 pytest-6.1.1 pytz-2020.1 scikit-image-0.17.2 scipy-1.5.2 sqlparse-0.4.1 tornado-6.0.4 tqdm-4.50.2 zipp-3.3.1

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
DATA_DIR = '/content/'

# %%
x_train_dir = os.path.join(DATA_DIR, 'training/images')
y_train_dir = os.path.join(DATA_DIR, 'training/1st_manual')

x_valid_dir = os.path.join(DATA_DIR, 'test/images')
y_valid_dir = os.path.join(DATA_DIR, 'test/1st_manual')

x_test_dir = os.path.join(DATA_DIR, 'test/images')
y_test_dir = os.path.join(DATA_DIR, 'test/1st_manual')

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

# %% [markdown]
# ### Dataloader
#
# Writing helper class for data extraction, tranformation and preprocessing
# https://pytorch.org/docs/stable/data

# %%
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset

# %%
import re
def sorted_alphanumeric(data):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(data, key=alphanum_key)
class Dataset(BaseDataset):
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['nonvessel', 'vessel']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        ## Original images
        self.ids = sorted_alphanumeric(os.listdir(images_dir))
        ## GroundTruth
        self.ids2 = sorted_alphanumeric(os.listdir(masks_dir))
        
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids2]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cla.lower()) for cla in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)/255
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['vessel'])

image, mask = dataset[4] # get some sample
visualize(
    image=image, 
    cars_mask=mask.squeeze(),
)

# %% [markdown]
# ### Augmentations

# %% [markdown]
# Data augmentation is a powerful technique to increase the amount of your data and prevent model overfitting.
# If you not familiar with such trick read some of these articles:
#  - [The Effectiveness of Data Augmentation in Image Classification using Deep
# Learning](http://cs231n.stanford.edu/reports/2017/pdfs/300.pdf)
#  - [Data Augmentation | How to use Deep Learning when you have Limited Data](https://medium.com/nanonets/how-to-use-deep-learning-when-you-have-limited-data-part-2-data-augmentation-c26971dc8ced)
#  - [Data Augmentation Experimentation](https://towardsdatascience.com/data-augmentation-experimentation-3e274504f04b)
#
# Since our dataset is very small we will apply a large number of different augmentations:
#  - horizontal flip
#  - affine transforms
#  - perspective transforms
#  - brightness/contrast/colors manipulations
#  - image bluring and sharpening
#  - gaussian noise
#  - random crops
#
# All this transforms can be easily applied with [**Albumentations**](https://github.com/albu/albumentations/) - fast augmentation library.
# For detailed explanation of image transformations you can look at [kaggle salt segmentation exmaple](https://github.com/albu/albumentations/blob/master/notebooks/example_kaggle_salt.ipynb) provided by [**Albumentations**](https://github.com/albu/albumentations/) authors.

# %%
import albumentations as albu

# %%
def get_training_augmentation():
    train_transform = [

        albu.HorizontalFlip(p=0.5),

        albu.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        albu.PadIfNeeded(min_height=320, min_width=320, always_apply=True, border_mode=0),
        albu.RandomCrop(height=320, width=320, always_apply=True),

        albu.IAAAdditiveGaussianNoise(p=0.2),
        albu.IAAPerspective(p=0.5),

        albu.OneOf(
            [
                albu.CLAHE(p=1),
                albu.RandomBrightness(p=1),
                albu.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        albu.OneOf(
            [
                albu.IAASharpen(p=1),
                albu.Blur(blur_limit=3, p=1),
                albu.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        albu.OneOf(
            [
                albu.RandomContrast(p=1),
                albu.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
    ]
    return albu.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        albu.PadIfNeeded(384*3, 480*3)
    ]
    return albu.Compose(test_transform)


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        albu.Lambda(image=preprocessing_fn),
        albu.Lambda(image=to_tensor, mask=to_tensor),
    ]
    return albu.Compose(_transform)

# %%
#### Visualize resulted augmented images and masks

augmented_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    augmentation=get_training_augmentation(), 
    classes=['vessel'],
)

# same image with different random transforms
for i in range(3):
    image, mask = augmented_dataset[1]
    visualize(image=image, mask=mask.squeeze(-1))

# %% [markdown]
# ## Create model and train

# %%
import torch
import numpy as np
import segmentation_models_pytorch as smp

# %%
ENCODER = 'efficientnet-b7'
ENCODER_WEIGHTS = 'imagenet'
CLASSES = ['vessel']
ACTIVATION = 'sigmoid' # could be None for logits or 'softmax2d' for multicalss segmentation
DEVICE = 'cuda'

# create segmentation model with pretrained encoder
model = smp.FPN(
    encoder_name=ENCODER, 
    encoder_weights=ENCODER_WEIGHTS, 
    classes=len(CLASSES), 
    activation=ACTIVATION,
)

preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %%
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    augmentation=get_training_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
    classes=CLASSES,
)

valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    augmentation=get_validation_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
    classes=CLASSES,
)

train_loader = DataLoader(train_dataset, batch_size=7, shuffle=True, num_workers=12)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=4)

# %%
# Dice/F1 score - https://en.wikipedia.org/wiki/S%C3%B8rensen%E2%80%93Dice_coefficient
# IoU/Jaccard score - https://en.wikipedia.org/wiki/Jaccard_index

#loss = smp.utils.losses.BCELoss()
loss = smp.utils.losses.DiceLoss()
metrics = [
    smp.utils.metrics.IoU(threshold=0.5),
]

optimizer = torch.optim.Adam([ 
    dict(params=model.parameters(), lr=0.0004),
])

# %%
# create epoch runners 
# it is a simple loop of iterating over dataloader`s samples
train_epoch = smp.utils.train.TrainEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

valid_epoch = smp.utils.train.ValidEpoch(
    model, 
    loss=loss, 
    metrics=metrics, 
    device=DEVICE,
    verbose=True,
)

# %%
# train model for 40 epochs

max_score = 0

for i in range(0, 5000):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = valid_epoch.run(valid_loader)
    
    # do something (save model, change lr, etc.)
    if max_score < valid_logs['iou_score']:
        max_score = valid_logs['iou_score']
        torch.save(model, './best_model.pth')
        print('Model saved!')
        
    if i % 200 == 0:
        optimizer.param_groups[0]['lr'] = optimizer.param_groups[0]['lr']*0.9
        print('Decrease decoder learning rate 10%')
# Out:
# Epoch: 0
# train: 100%|██████████| 3/3 [00:03<00:00,  1.24s/it, dice_loss - 0.268, iou_score - 0.5838]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2672, iou_score - 0.5829]
# Model saved!
# Decrease decoder learning rate 10%
#
# Epoch: 1
# train: 100%|██████████| 3/3 [00:03<00:00,  1.21s/it, dice_loss - 0.2488, iou_score - 0.6084]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2677, iou_score - 0.5823]
#
# Epoch: 2
# train: 100%|██████████| 3/3 [00:03<00:00,  1.21s/it, dice_loss - 0.2547, iou_score - 0.6013]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2621, iou_score - 0.5895]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2747, iou_score - 0.5762]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2615, iou_score - 0.5901]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 3/3 [00:03<00:00,  1.21s/it, dice_loss - 0.2629, iou_score - 0.5908]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.26, iou_score - 0.5919]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2505, iou_score - 0.6055]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2601, iou_score - 0.5915]
#
# Epoch: 6
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2476, iou_score - 0.6093]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.263, iou_score - 0.588]
#
# Epoch: 7
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2347, iou_score - 0.6258]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2635, iou_score - 0.5874]
#
# Epoch: 8
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2584, iou_score - 0.5955]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2608, iou_score - 0.591]
#
# Epoch: 9
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2674, iou_score - 0.5859]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2628, iou_score - 0.589]
#
# Epoch: 10
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2562, iou_score - 0.6004]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.26, iou_score - 0.5923]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2719, iou_score - 0.5797]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2593, iou_score - 0.5927]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2734, iou_score - 0.5758]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2613, iou_score - 0.5903]
#
# Epoch: 13
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2623, iou_score - 0.5909]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2643, iou_score - 0.5868]
#
# Epoch: 14
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2508, iou_score - 0.6071]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2628, iou_score - 0.5887]
#
# Epoch: 15
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2624, iou_score - 0.5908]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2602, iou_score - 0.5917]
#
# Epoch: 16
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2711, iou_score - 0.5794]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.11it/s, dice_loss - 0.2595, iou_score - 0.5926]
#
# Epoch: 17
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2623, iou_score - 0.5918]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2596, iou_score - 0.5925]
#
# Epoch: 18
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2608, iou_score - 0.5931]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2614, iou_score - 0.5905]
#
# Epoch: 19
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2649, iou_score - 0.5891]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2623, iou_score - 0.5895]
#
# Epoch: 20
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2437, iou_score - 0.6149]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2606, iou_score - 0.5915]
#
# Epoch: 21
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.266, iou_score - 0.5869]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2594, iou_score - 0.5928]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2649, iou_score - 0.588]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2606, iou_score - 0.5909]
#
# Epoch: 23
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2538, iou_score - 0.6016]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2612, iou_score - 0.5902]
#
# Epoch: 24
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2612, iou_score - 0.5927]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2608, iou_score - 0.5909]
#
# Epoch: 25
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2606, iou_score - 0.5933]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2629, iou_score - 0.5886]
#
# Epoch: 26
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2558, iou_score - 0.5998]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2616, iou_score - 0.5903]
#
# Epoch: 27
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2777, iou_score - 0.5717]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2586, iou_score - 0.5937]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2577, iou_score - 0.5964]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.259, iou_score - 0.5931]
#
# Epoch: 29
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2534, iou_score - 0.6013]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2601, iou_score - 0.5915]
#
# Epoch: 30
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2626, iou_score - 0.5907]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2618, iou_score - 0.5891]
#
# Epoch: 31
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2691, iou_score - 0.5819]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2616, iou_score - 0.5895]
#
# Epoch: 32
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2417, iou_score - 0.6171]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2608, iou_score - 0.5911]
#
# Epoch: 33
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2602, iou_score - 0.5939]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.11it/s, dice_loss - 0.2593, iou_score - 0.5932]
#
# Epoch: 34
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2667, iou_score - 0.5862]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2595, iou_score - 0.5931]
#
# Epoch: 35
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2566, iou_score - 0.5986]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2595, iou_score - 0.5927]
#
# Epoch: 36
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2489, iou_score - 0.6089]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2602, iou_score - 0.5916]
#
# Epoch: 37
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2451, iou_score - 0.6135]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2594, iou_score - 0.5929]
#
# Epoch: 38
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2679, iou_score - 0.585]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2593, iou_score - 0.5931]
#
# Epoch: 39
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2574, iou_score - 0.5969]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2585, iou_score - 0.5936]
#
# Epoch: 40
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2362, iou_score - 0.6245]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.26, iou_score - 0.5914]
#
# Epoch: 41
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2673, iou_score - 0.5847]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2602, iou_score - 0.5912]
#
# Epoch: 42
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2578, iou_score - 0.5964]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.04it/s, dice_loss - 0.2607, iou_score - 0.5908]
#
# Epoch: 43
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.242, iou_score - 0.6172]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2614, iou_score - 0.5899]
#
# Epoch: 44
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2808, iou_score - 0.5678]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2624, iou_score - 0.5889]
#
# Epoch: 45
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2498, iou_score - 0.6077]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2622, iou_score - 0.5892]
#
# Epoch: 46
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2629, iou_score - 0.5901]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2612, iou_score - 0.5902]
#
# Epoch: 47
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2677, iou_score - 0.5841]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.261, iou_score - 0.5903]
#
# Epoch: 48
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2515, iou_score - 0.6052]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2602, iou_score - 0.5915]
#
# Epoch: 49
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2564, iou_score - 0.5989]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2594, iou_score - 0.5927]
#
# Epoch: 50
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2703, iou_score - 0.5813]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2592, iou_score - 0.5928]
#
# Epoch: 51
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2676, iou_score - 0.5853]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2601, iou_score - 0.5915]
#
# Epoch: 52
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2516, iou_score - 0.6043]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2605, iou_score - 0.5908]
#
# Epoch: 53
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2701, iou_score - 0.5805]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2594, iou_score - 0.5923]
#
# Epoch: 54
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2641, iou_score - 0.5895]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2584, iou_score - 0.594]
# Model saved!
#
# Epoch: 55
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2474, iou_score - 0.6116]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.261, iou_score - 0.5908]
#
# Epoch: 56
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2583, iou_score - 0.5965]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2622, iou_score - 0.5889]
#
# Epoch: 57
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2364, iou_score - 0.6242]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2604, iou_score - 0.591]
#
# Epoch: 58
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2855, iou_score - 0.5629]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2591, iou_score - 0.5928]
#
# Epoch: 59
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2542, iou_score - 0.6016]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2604, iou_score - 0.5916]
#
# Epoch: 60
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2339, iou_score - 0.6292]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2609, iou_score - 0.5911]
#
# Epoch: 61
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2743, iou_score - 0.577]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2596, iou_score - 0.5926]
#
# Epoch: 62
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2529, iou_score - 0.6037]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2601, iou_score - 0.592]
#
# Epoch: 63
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2509, iou_score - 0.6059]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2601, iou_score - 0.5917]
#
# Epoch: 64
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2868, iou_score - 0.5604]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.261, iou_score - 0.5905]
#
# Epoch: 65
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2352, iou_score - 0.6259]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2611, iou_score - 0.5904]
#
# Epoch: 66
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2465, iou_score - 0.6112]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2605, iou_score - 0.5911]
#
# Epoch: 67
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2744, iou_score - 0.5753]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2613, iou_score - 0.5902]
#
# Epoch: 68
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2503, iou_score - 0.606]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2634, iou_score - 0.5875]
#
# Epoch: 69
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2618, iou_score - 0.5931]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2662, iou_score - 0.5837]
#
# Epoch: 70
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2502, iou_score - 0.6063]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2678, iou_score - 0.5818]
#
# Epoch: 71
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2566, iou_score - 0.5976]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2642, iou_score - 0.5865]
#
# Epoch: 72
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2603, iou_score - 0.5937]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2617, iou_score - 0.59]
#
# Epoch: 73
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2433, iou_score - 0.6156]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2595, iou_score - 0.5926]
#
# Epoch: 74
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2464, iou_score - 0.6115]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.04it/s, dice_loss - 0.2589, iou_score - 0.5931]
#
# Epoch: 75
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2607, iou_score - 0.5942]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2599, iou_score - 0.592]
#
# Epoch: 76
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2598, iou_score - 0.5945]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2621, iou_score - 0.5895]
#
# Epoch: 77
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2553, iou_score - 0.6003]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2627, iou_score - 0.5883]
#
# Epoch: 78
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2549, iou_score - 0.5998]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.11it/s, dice_loss - 0.2619, iou_score - 0.5888]
#
# Epoch: 79
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2403, iou_score - 0.6184]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2602, iou_score - 0.5912]
#
# Epoch: 80
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2351, iou_score - 0.625]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2598, iou_score - 0.5919]
#
# Epoch: 81
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2741, iou_score - 0.5757]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.261, iou_score - 0.5906]
#
# Epoch: 82
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2661, iou_score - 0.5857]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2616, iou_score - 0.5898]
#
# Epoch: 83
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2611, iou_score - 0.5929]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2619, iou_score - 0.5893]
#
# Epoch: 84
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2553, iou_score - 0.6014]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2626, iou_score - 0.5881]
#
# Epoch: 85
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2938, iou_score - 0.5525]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2618, iou_score - 0.5888]
#
# Epoch: 86
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2747, iou_score - 0.5751]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2599, iou_score - 0.5914]
#
# Epoch: 87
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2396, iou_score - 0.6205]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2592, iou_score - 0.5924]
#
# Epoch: 88
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2319, iou_score - 0.6297]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2585, iou_score - 0.5934]
#
# Epoch: 89
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2406, iou_score - 0.6193]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2611, iou_score - 0.5908]
#
# Epoch: 90
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2313, iou_score - 0.6323]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.11it/s, dice_loss - 0.2606, iou_score - 0.5912]
#
# Epoch: 91
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2605, iou_score - 0.5934]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2599, iou_score - 0.5919]
#
# Epoch: 92
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2743, iou_score - 0.5767]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2598, iou_score - 0.5916]
#
# Epoch: 93
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.264, iou_score - 0.5885]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2597, iou_score - 0.5916]
#
# Epoch: 94
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2701, iou_score - 0.5812]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2592, iou_score - 0.5923]
#
# Epoch: 95
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2496, iou_score - 0.6078]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2587, iou_score - 0.5928]
#
# Epoch: 96
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2394, iou_score - 0.6208]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2586, iou_score - 0.593]
#
# Epoch: 97
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2658, iou_score - 0.586]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2574, iou_score - 0.5947]
# Model saved!
#
# Epoch: 98
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2596, iou_score - 0.5939]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2572, iou_score - 0.595]
# Model saved!
#
# Epoch: 99
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2446, iou_score - 0.6127]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2565, iou_score - 0.5959]
# Model saved!
#
# Epoch: 100
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2621, iou_score - 0.5911]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2569, iou_score - 0.5958]
#
# Epoch: 101
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2743, iou_score - 0.5766]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.258, iou_score - 0.5944]
#
# Epoch: 102
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2473, iou_score - 0.6095]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2578, iou_score - 0.5946]
#
# Epoch: 103
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2563, iou_score - 0.5998]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2575, iou_score - 0.5947]
#
# Epoch: 104
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2532, iou_score - 0.6024]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2574, iou_score - 0.5947]
#
# Epoch: 105
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2518, iou_score - 0.6043]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2575, iou_score - 0.5946]
#
# Epoch: 106
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2578, iou_score - 0.5969]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2585, iou_score - 0.5936]
#
# Epoch: 107
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2492, iou_score - 0.6083]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2582, iou_score - 0.5938]
#
# Epoch: 108
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2644, iou_score - 0.5869]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2587, iou_score - 0.5929]
#
# Epoch: 109
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.268, iou_score - 0.583]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2587, iou_score - 0.5927]
#
# Epoch: 110
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.273, iou_score - 0.5773]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2584, iou_score - 0.5934]
#
# Epoch: 111
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2863, iou_score - 0.5646]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2592, iou_score - 0.5926]
#
# Epoch: 112
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.257, iou_score - 0.5991]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2588, iou_score - 0.5929]
#
# Epoch: 113
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2439, iou_score - 0.614]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2596, iou_score - 0.5917]
#
# Epoch: 114
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2651, iou_score - 0.5877]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2583, iou_score - 0.5938]
#
# Epoch: 115
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2602, iou_score - 0.5957]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2579, iou_score - 0.5943]
#
# Epoch: 116
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2548, iou_score - 0.6005]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2584, iou_score - 0.5934]
#
# Epoch: 117
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2646, iou_score - 0.5881]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2579, iou_score - 0.5939]
#
# Epoch: 118
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2587, iou_score - 0.5955]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2586, iou_score - 0.5928]
#
# Epoch: 119
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2633, iou_score - 0.5893]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2583, iou_score - 0.5935]
#
# Epoch: 120
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.248, iou_score - 0.6084]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2591, iou_score - 0.5929]
#
# Epoch: 121
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2637, iou_score - 0.5895]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2578, iou_score - 0.5941]
#
# Epoch: 122
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.261, iou_score - 0.5921]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2574, iou_score - 0.5944]
#
# Epoch: 123
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2887, iou_score - 0.5582]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2575, iou_score - 0.5944]
#
# Epoch: 124
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2539, iou_score - 0.6026]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2579, iou_score - 0.5937]
#
# Epoch: 125
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2472, iou_score - 0.6096]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2581, iou_score - 0.5935]
#
# Epoch: 126
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2454, iou_score - 0.6124]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2591, iou_score - 0.5927]
#
# Epoch: 127
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2472, iou_score - 0.6105]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2599, iou_score - 0.592]
#
# Epoch: 128
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2458, iou_score - 0.6138]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2596, iou_score - 0.5919]
#
# Epoch: 129
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2531, iou_score - 0.6036]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2599, iou_score - 0.5912]
#
# Epoch: 130
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2526, iou_score - 0.6028]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2584, iou_score - 0.5929]
#
# Epoch: 131
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2612, iou_score - 0.5916]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.11it/s, dice_loss - 0.258, iou_score - 0.5935]
#
# Epoch: 132
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2714, iou_score - 0.5785]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2594, iou_score - 0.5921]
#
# Epoch: 133
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.242, iou_score - 0.6178]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2634, iou_score - 0.5874]
#
# Epoch: 134
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2608, iou_score - 0.5936]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2657, iou_score - 0.5846]
#
# Epoch: 135
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2546, iou_score - 0.6028]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2621, iou_score - 0.5885]
#
# Epoch: 136
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2478, iou_score - 0.6087]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2624, iou_score - 0.5877]
#
# Epoch: 137
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2679, iou_score - 0.5825]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2625, iou_score - 0.5876]
#
# Epoch: 138
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2602, iou_score - 0.5922]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2636, iou_score - 0.5865]
#
# Epoch: 139
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.251, iou_score - 0.6059]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2664, iou_score - 0.5838]
#
# Epoch: 140
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2549, iou_score - 0.6012]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2612, iou_score - 0.5901]
#
# Epoch: 141
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2521, iou_score - 0.6051]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2599, iou_score - 0.5912]
#
# Epoch: 142
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2738, iou_score - 0.5771]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2626, iou_score - 0.5876]
#
# Epoch: 143
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2901, iou_score - 0.5553]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2631, iou_score - 0.5871]
#
# Epoch: 144
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2472, iou_score - 0.6098]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2638, iou_score - 0.5869]
#
# Epoch: 145
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2514, iou_score - 0.6047]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2621, iou_score - 0.5889]
#
# Epoch: 146
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2649, iou_score - 0.5868]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2618, iou_score - 0.5889]
#
# Epoch: 147
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2595, iou_score - 0.5943]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2605, iou_score - 0.5905]
#
# Epoch: 148
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2529, iou_score - 0.6027]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2621, iou_score - 0.589]
#
# Epoch: 149
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.266, iou_score - 0.5878]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2637, iou_score - 0.5869]
#
# Epoch: 150
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2601, iou_score - 0.5937]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2649, iou_score - 0.5849]
#
# Epoch: 151
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2905, iou_score - 0.5548]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2644, iou_score - 0.5852]
#
# Epoch: 152
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2414, iou_score - 0.6163]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2622, iou_score - 0.5883]
#
# Epoch: 153
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2633, iou_score - 0.5896]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2632, iou_score - 0.5876]
#
# Epoch: 154
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.235, iou_score - 0.6264]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2617, iou_score - 0.5894]
#
# Epoch: 155
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2785, iou_score - 0.5706]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2608, iou_score - 0.5902]
#
# Epoch: 156
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.233, iou_score - 0.6276]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2638, iou_score - 0.5865]
#
# Epoch: 157
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.254, iou_score - 0.6015]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2639, iou_score - 0.5864]
#
# Epoch: 158
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2485, iou_score - 0.6071]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2615, iou_score - 0.5897]
#
# Epoch: 159
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2494, iou_score - 0.6074]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2602, iou_score - 0.5913]
#
# Epoch: 160
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2591, iou_score - 0.5944]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2588, iou_score - 0.5926]
#
# Epoch: 161
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2511, iou_score - 0.6039]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2586, iou_score - 0.5929]
#
# Epoch: 162
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2841, iou_score - 0.563]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2595, iou_score - 0.5919]
#
# Epoch: 163
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2333, iou_score - 0.6274]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2632, iou_score - 0.5873]
#
# Epoch: 164
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2624, iou_score - 0.5909]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2614, iou_score - 0.5895]
#
# Epoch: 165
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2491, iou_score - 0.6075]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2583, iou_score - 0.5934]
#
# Epoch: 166
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2347, iou_score - 0.626]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2578, iou_score - 0.5941]
#
# Epoch: 167
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2613, iou_score - 0.5915]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2586, iou_score - 0.5933]
#
# Epoch: 168
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2596, iou_score - 0.5933]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2598, iou_score - 0.5918]
#
# Epoch: 169
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2815, iou_score - 0.5661]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2609, iou_score - 0.5903]
#
# Epoch: 170
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2543, iou_score - 0.5998]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2621, iou_score - 0.5886]
#
# Epoch: 171
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.252, iou_score - 0.6034]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2625, iou_score - 0.5881]
#
# Epoch: 172
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.252, iou_score - 0.6032]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2631, iou_score - 0.5875]
#
# Epoch: 173
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2657, iou_score - 0.5859]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2637, iou_score - 0.5869]
#
# Epoch: 174
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2569, iou_score - 0.5973]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2629, iou_score - 0.588]
#
# Epoch: 175
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2529, iou_score - 0.603]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2637, iou_score - 0.587]
#
# Epoch: 176
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2852, iou_score - 0.5617]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2645, iou_score - 0.5858]
#
# Epoch: 177
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2725, iou_score - 0.5787]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2656, iou_score - 0.5845]
#
# Epoch: 178
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2525, iou_score - 0.6037]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2634, iou_score - 0.5872]
#
# Epoch: 179
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2836, iou_score - 0.5651]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2655, iou_score - 0.5849]
#
# Epoch: 180
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2298, iou_score - 0.6325]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2649, iou_score - 0.5855]
#
# Epoch: 181
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.257, iou_score - 0.5979]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2634, iou_score - 0.587]
#
# Epoch: 182
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2509, iou_score - 0.6046]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.261, iou_score - 0.5898]
#
# Epoch: 183
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2564, iou_score - 0.598]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2595, iou_score - 0.5919]
#
# Epoch: 184
# train: 100%|██████████| 3/3 [00:03<00:00,  1.25s/it, dice_loss - 0.2568, iou_score - 0.5975]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2613, iou_score - 0.59]
#
# Epoch: 185
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.259, iou_score - 0.5947]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2633, iou_score - 0.5873]
#
# Epoch: 186
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2648, iou_score - 0.5874]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2584, iou_score - 0.5933]
#
# Epoch: 187
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.23, iou_score - 0.6326]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2582, iou_score - 0.5935]
#
# Epoch: 188
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2642, iou_score - 0.589]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2584, iou_score - 0.5934]
#
# Epoch: 189
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2488, iou_score - 0.6069]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2585, iou_score - 0.5934]
#
# Epoch: 190
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2646, iou_score - 0.5875]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.258, iou_score - 0.5939]
#
# Epoch: 191
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2643, iou_score - 0.5881]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2587, iou_score - 0.5929]
#
# Epoch: 192
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2532, iou_score - 0.6013]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2608, iou_score - 0.5903]
#
# Epoch: 193
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2325, iou_score - 0.6283]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2626, iou_score - 0.5882]
#
# Epoch: 194
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2796, iou_score - 0.5687]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2598, iou_score - 0.5916]
#
# Epoch: 195
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2752, iou_score - 0.5739]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.258, iou_score - 0.5937]
#
# Epoch: 196
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.256, iou_score - 0.5977]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2584, iou_score - 0.5934]
#
# Epoch: 197
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2527, iou_score - 0.6023]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2601, iou_score - 0.5915]
#
# Epoch: 198
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2613, iou_score - 0.593]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2634, iou_score - 0.5875]
#
# Epoch: 199
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2343, iou_score - 0.6258]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2583, iou_score - 0.5934]
#
# Epoch: 200
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2465, iou_score - 0.6101]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.259, iou_score - 0.592]
# Decrease decoder learning rate 10%
#
# Epoch: 201
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2509, iou_score - 0.6043]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2591, iou_score - 0.5921]
#
# Epoch: 202
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2481, iou_score - 0.6095]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2588, iou_score - 0.5929]
#
# Epoch: 203
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2395, iou_score - 0.6197]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2613, iou_score - 0.59]
#
# Epoch: 204
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2248, iou_score - 0.6394]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.263, iou_score - 0.588]
#
# Epoch: 205
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2563, iou_score - 0.5984]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.26, iou_score - 0.5914]
#
# Epoch: 206
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2565, iou_score - 0.5968]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2582, iou_score - 0.5933]
#
# Epoch: 207
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2436, iou_score - 0.6141]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2578, iou_score - 0.5936]
#
# Epoch: 208
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2586, iou_score - 0.5941]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2576, iou_score - 0.5941]
#
# Epoch: 209
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2581, iou_score - 0.5965]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2575, iou_score - 0.5945]
#
# Epoch: 210
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2693, iou_score - 0.5819]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2579, iou_score - 0.594]
#
# Epoch: 211
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2573, iou_score - 0.597]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2576, iou_score - 0.5943]
#
# Epoch: 212
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2358, iou_score - 0.625]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2587, iou_score - 0.5929]
#
# Epoch: 213
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2423, iou_score - 0.617]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2602, iou_score - 0.5909]
#
# Epoch: 214
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2724, iou_score - 0.5779]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2623, iou_score - 0.5881]
#
# Epoch: 215
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2724, iou_score - 0.5771]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2632, iou_score - 0.5869]
#
# Epoch: 216
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2719, iou_score - 0.5779]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.261, iou_score - 0.5896]
#
# Epoch: 217
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2636, iou_score - 0.5885]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2595, iou_score - 0.5914]
#
# Epoch: 218
# train: 100%|██████████| 3/3 [00:03<00:00,  1.21s/it, dice_loss - 0.2594, iou_score - 0.5931]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2594, iou_score - 0.5916]
#
# Epoch: 219
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2572, iou_score - 0.5968]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2595, iou_score - 0.5917]
#
# Epoch: 220
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2439, iou_score - 0.6137]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2602, iou_score - 0.5908]
#
# Epoch: 221
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2415, iou_score - 0.6164]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2611, iou_score - 0.5897]
#
# Epoch: 222
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2478, iou_score - 0.6081]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.262, iou_score - 0.5887]
#
# Epoch: 223
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2701, iou_score - 0.5805]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2612, iou_score - 0.5895]
#
# Epoch: 224
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2638, iou_score - 0.5894]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2601, iou_score - 0.5909]
#
# Epoch: 225
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2766, iou_score - 0.5721]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2618, iou_score - 0.589]
#
# Epoch: 226
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2516, iou_score - 0.6036]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2641, iou_score - 0.5862]
#
# Epoch: 227
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2504, iou_score - 0.6062]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.263, iou_score - 0.5874]
#
# Epoch: 228
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2373, iou_score - 0.6227]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2603, iou_score - 0.5905]
#
# Epoch: 229
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2685, iou_score - 0.5825]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2592, iou_score - 0.592]
#
# Epoch: 230
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2524, iou_score - 0.6025]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2602, iou_score - 0.5911]
#
# Epoch: 231
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2572, iou_score - 0.5965]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2622, iou_score - 0.5885]
#
# Epoch: 232
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.235, iou_score - 0.6274]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2625, iou_score - 0.588]
#
# Epoch: 233
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2463, iou_score - 0.611]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2598, iou_score - 0.5911]
#
# Epoch: 234
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2691, iou_score - 0.5815]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2594, iou_score - 0.5918]
#
# Epoch: 235
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.245, iou_score - 0.6118]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2604, iou_score - 0.5907]
#
# Epoch: 236
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2331, iou_score - 0.6271]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.262, iou_score - 0.5886]
#
# Epoch: 237
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2625, iou_score - 0.5904]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2618, iou_score - 0.5889]
#
# Epoch: 238
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2594, iou_score - 0.5932]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2606, iou_score - 0.5902]
#
# Epoch: 239
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2515, iou_score - 0.6036]
# ...
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2587, iou_score - 0.5923]
#
# Epoch: 453
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.259, iou_score - 0.5934]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2589, iou_score - 0.592]
#
# Epoch: 454
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2586, iou_score - 0.5932]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2609, iou_score - 0.5894]
#
# Epoch: 455
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2645, iou_score - 0.5875]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2628, iou_score - 0.5869]
#
# Epoch: 456
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2849, iou_score - 0.5609]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2609, iou_score - 0.5894]
#
# Epoch: 457
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2552, iou_score - 0.598]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2588, iou_score - 0.5921]
#
# Epoch: 458
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2343, iou_score - 0.6257]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2578, iou_score - 0.5935]
#
# Epoch: 459
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2427, iou_score - 0.6141]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2577, iou_score - 0.5935]
#
# Epoch: 460
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2481, iou_score - 0.6074]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2583, iou_score - 0.5928]
#
# Epoch: 461
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2693, iou_score - 0.581]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2581, iou_score - 0.5931]
#
# Epoch: 462
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2435, iou_score - 0.6139]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2578, iou_score - 0.5936]
#
# Epoch: 463
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2361, iou_score - 0.623]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.257, iou_score - 0.5946]
#
# Epoch: 464
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2344, iou_score - 0.6256]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2563, iou_score - 0.5952]
#
# Epoch: 465
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2639, iou_score - 0.5874]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.258, iou_score - 0.5927]
#
# Epoch: 466
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2416, iou_score - 0.615]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2578, iou_score - 0.5932]
#
# Epoch: 467
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2389, iou_score - 0.6196]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2591, iou_score - 0.5919]
#
# Epoch: 468
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.25, iou_score - 0.606]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2601, iou_score - 0.5907]
#
# Epoch: 469
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2444, iou_score - 0.6125]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2586, iou_score - 0.5925]
#
# Epoch: 470
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2374, iou_score - 0.6216]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2572, iou_score - 0.5942]
#
# Epoch: 471
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2536, iou_score - 0.6007]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2574, iou_score - 0.5941]
#
# Epoch: 472
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2588, iou_score - 0.5938]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2578, iou_score - 0.5936]
#
# Epoch: 473
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2279, iou_score - 0.6355]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2576, iou_score - 0.5938]
#
# Epoch: 474
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2354, iou_score - 0.6237]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2575, iou_score - 0.5937]
#
# Epoch: 475
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.25, iou_score - 0.6059]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2579, iou_score - 0.5931]
#
# Epoch: 476
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2431, iou_score - 0.6148]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.04it/s, dice_loss - 0.2589, iou_score - 0.5922]
#
# Epoch: 477
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2665, iou_score - 0.5861]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2598, iou_score - 0.5911]
#
# Epoch: 478
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2614, iou_score - 0.5913]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2594, iou_score - 0.5913]
#
# Epoch: 479
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2344, iou_score - 0.625]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.04it/s, dice_loss - 0.2596, iou_score - 0.5908]
#
# Epoch: 480
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.24, iou_score - 0.6185]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2586, iou_score - 0.5921]
#
# Epoch: 481
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2556, iou_score - 0.5991]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2586, iou_score - 0.5923]
#
# Epoch: 482
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2351, iou_score - 0.625]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2591, iou_score - 0.5918]
#
# Epoch: 483
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2563, iou_score - 0.5982]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2581, iou_score - 0.593]
#
# Epoch: 484
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2498, iou_score - 0.606]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2575, iou_score - 0.5937]
#
# Epoch: 485
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2499, iou_score - 0.6062]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2585, iou_score - 0.5923]
#
# Epoch: 486
# train: 100%|██████████| 3/3 [00:03<00:00,  1.22s/it, dice_loss - 0.2387, iou_score - 0.6197]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2591, iou_score - 0.5917]
#
# Epoch: 487
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2382, iou_score - 0.6205]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2584, iou_score - 0.5928]
#
# Epoch: 488
# train: 100%|██████████| 3/3 [00:03<00:00,  1.15s/it, dice_loss - 0.2668, iou_score - 0.5842]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.04it/s, dice_loss - 0.2588, iou_score - 0.5925]
#
# Epoch: 489
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2512, iou_score - 0.6075]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2599, iou_score - 0.5911]
#
# Epoch: 490
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2469, iou_score - 0.6085]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2582, iou_score - 0.5928]
#
# Epoch: 491
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2555, iou_score - 0.5977]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2575, iou_score - 0.5936]
#
# Epoch: 492
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2527, iou_score - 0.6007]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2562, iou_score - 0.5951]
#
# Epoch: 493
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2541, iou_score - 0.5988]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2566, iou_score - 0.5947]
#
# Epoch: 494
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2719, iou_score - 0.5777]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2571, iou_score - 0.5944]
#
# Epoch: 495
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2312, iou_score - 0.6307]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2565, iou_score - 0.5952]
#
# Epoch: 496
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2553, iou_score - 0.5997]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2562, iou_score - 0.5955]
#
# Epoch: 497
# train: 100%|██████████| 3/3 [00:03<00:00,  1.16s/it, dice_loss - 0.2611, iou_score - 0.5904]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2572, iou_score - 0.5943]
#
# Epoch: 498
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2371, iou_score - 0.6225]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2569, iou_score - 0.5947]
#
# Epoch: 499
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2571, iou_score - 0.5959]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.10it/s, dice_loss - 0.2566, iou_score - 0.5948]
#
# Epoch: 500
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2552, iou_score - 0.5986]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.2568, iou_score - 0.5946]
#
# Epoch: 501
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2447, iou_score - 0.6123]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.04it/s, dice_loss - 0.2567, iou_score - 0.5948]
#
# Epoch: 502
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2348, iou_score - 0.625]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2584, iou_score - 0.5928]
#
# Epoch: 503
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2535, iou_score - 0.6004]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2611, iou_score - 0.5894]
#
# Epoch: 504
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2398, iou_score - 0.6183]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2595, iou_score - 0.5914]
#
# Epoch: 505
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2438, iou_score - 0.6139]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2569, iou_score - 0.5946]
#
# Epoch: 506
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2402, iou_score - 0.6194]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2561, iou_score - 0.5955]
#
# Epoch: 507
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2473, iou_score - 0.6084]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.05it/s, dice_loss - 0.255, iou_score - 0.5969]
#
# Epoch: 508
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2745, iou_score - 0.5749]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2546, iou_score - 0.5974]
#
# Epoch: 509
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2555, iou_score - 0.5993]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2548, iou_score - 0.5972]
#
# Epoch: 510
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2645, iou_score - 0.587]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2543, iou_score - 0.5979]
# Model saved!
#
# Epoch: 511
# train: 100%|██████████| 3/3 [00:03<00:00,  1.21s/it, dice_loss - 0.2441, iou_score - 0.6138]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.254, iou_score - 0.5982]
# Model saved!
#
# Epoch: 512
# train: 100%|██████████| 3/3 [00:03<00:00,  1.22s/it, dice_loss - 0.2465, iou_score - 0.6093]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2562, iou_score - 0.5956]
#
# Epoch: 513
# train: 100%|██████████| 3/3 [00:03<00:00,  1.14s/it, dice_loss - 0.2597, iou_score - 0.593]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2587, iou_score - 0.5924]
#
# Epoch: 514
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2492, iou_score - 0.6065]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2589, iou_score - 0.5922]
#
# Epoch: 515
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2488, iou_score - 0.6074]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.257, iou_score - 0.5943]
#
# Epoch: 516
# train: 100%|██████████| 3/3 [00:03<00:00,  1.17s/it, dice_loss - 0.2418, iou_score - 0.6162]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2571, iou_score - 0.5939]
#
# Epoch: 517
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2694, iou_score - 0.5795]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.08it/s, dice_loss - 0.2575, iou_score - 0.5934]
#
# Epoch: 518
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2195, iou_score - 0.6455]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.09it/s, dice_loss - 0.2603, iou_score - 0.59]
#
# Epoch: 519
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.2673, iou_score - 0.5831]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.262, iou_score - 0.5881]
#
# Epoch: 520
# train: 100%|██████████| 3/3 [00:03<00:00,  1.20s/it, dice_loss - 0.2245, iou_score - 0.6384]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2594, iou_score - 0.5915]
#
# Epoch: 521
# train: 100%|██████████| 3/3 [00:03<00:00,  1.19s/it, dice_loss - 0.253, iou_score - 0.6008]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.06it/s, dice_loss - 0.2577, iou_score - 0.5937]
#
# Epoch: 522
# train: 100%|██████████| 3/3 [00:03<00:00,  1.18s/it, dice_loss - 0.2301, iou_score - 0.6308]
# valid: 100%|██████████| 20/20 [00:09<00:00,  2.07it/s, dice_loss - 0.2579, iou_score - 0.5932]
#
# Epoch: 523
# train:  33%|███▎      | 1/3 [00:02<00:04,  2.28s/it, dice_loss - 0.2185, iou_score - 0.6458]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-2790632fe6f7> in <module>()
#       6
#       7     print('\nEpoch: {}'.format(i))
# ----> 8     train_logs = train_epoch.run(train_loader)
#       9     valid_logs = valid_epoch.run(valid_loader)
#      10
#
# /usr/local/lib/python3.6/dist-packages/segmentation_models_pytorch/utils/train.py in run(self, dataloader)
#      45             for x, y in iterator:
#      46                 x, y = x.to(self.device), y.to(self.device)
# ---> 47                 loss, y_pred = self.batch_update(x, y)
#      48
#      49                 # update loss logs
#
# /usr/local/lib/python3.6/dist-packages/segmentation_models_pytorch/utils/train.py in batch_update(self, x, y)
#      87         prediction = self.model.forward(x)
#      88         loss = self.loss(prediction, y)
# ---> 89         loss.backward()
#      90         self.optimizer.step()
#      91         return loss, prediction
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test best saved model

# %%
# load best saved checkpoint
best_model = torch.load('./best_model.pth')

# %%
# create test dataset
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    augmentation=get_validation_augmentation(), 
    preprocessing=get_preprocessing(preprocessing_fn),
    classes=CLASSES,
)

test_dataloader = DataLoader(test_dataset)

# %%
# evaluate model on test set
test_epoch = smp.utils.train.ValidEpoch(
    model=best_model,
    loss=loss,
    metrics=metrics,
    device=DEVICE,
)

logs = test_epoch.run(test_dataloader)
# Out:
# valid: 100%|██████████| 20/20 [00:03<00:00,  5.34it/s, dice_loss - 0.3454, iou_score - 0.5022]

# %% [markdown]
# ## Visualize predictions

# %%
# test dataset without transformations for image visualization
test_dataset_vis = Dataset(
    x_test_dir, y_test_dir, 
    classes=CLASSES,
)

# %%
for i in range(5):
    n = np.random.choice(len(test_dataset))
    
    image_vis = test_dataset_vis[n][0].astype('uint8')
    image, gt_mask = test_dataset[n]
    
    gt_mask = gt_mask.squeeze()
    
    x_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
    pr_mask = best_model.predict(x_tensor)
    pr_mask = (pr_mask.squeeze().cpu().numpy().round())
        
    visualize(
        image=image_vis, 
        ground_truth_mask=gt_mask, 
        predicted_mask=pr_mask
    )
